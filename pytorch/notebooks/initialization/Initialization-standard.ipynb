# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn
import numpy as np
import math
import pandas as pd
import os
from copy import deepcopy

# %%
import sys
sys.path.insert(0, '/Users/karlhajjar/Documents/projects/wide-networks/')

import utils
from utils.plot.initialization.network import FCNetwork, define_networks
from utils.plot.initialization.graphs import *
from utils.plot import set_plot_fonts
from utils.tools import set_random_seeds

# %% [markdown]
# # Constants

# %%
sigma = nn.ReLU()
d = 100  # dimension of the input data
n = int(1e3)  # number of samples considered

Ms = [50, 200, 500, 1000, 2000, 5000, 8000]  #, 10000 , 20000, 50000
n_trials = 10
L = 5

x = 2 * torch.rand((n,d))
y = x.mean(axis=1)  # target for each sample is the mean over the d dimensions of the values of the components
batch_size = 256

figsize = (11,8)

# set the figure directory for the notebook
figures_dir = '/Users/karlhajjar/Documents/projects/wide-networks/figures/initialization/standard/'
utils.plot.initialization.graphs.figures_dir = figures_dir

# %%
fonts_map = {'axes': {'titlesize': 20, 'labelsize': 18},
             'xtick': {'labelsize': 18},
             'ytick': {'labelsize': 18},
             'legend': {'fontsize': 16}}

set_plot_fonts(fonts_map)
sns.set_palette("deep")

# %%
set_random_seeds()

# %% [markdown]
# # 1. Glorot init without any scaling

# %%
scaling = None
init = 'glorot_uniform'
init_params = {'gain': 1.0}
scale_init = None
bias = False

# %% [markdown]
# ### 1.1. Layers' outputs

# %%
generate_outputs_plots(figsize, L, Ms, d, x, init, init_params, n_trials, scaling, bias=False)

# %% [markdown]
# ## 1.2 Layer's gradients

# %%
generate_gradients_plots(figsize, L, Ms, d, x, init, init_params, n_trials, scaling, bias=False)

# %% [markdown]
# # 2. He fan_in init without any scaling

# %%
scaling = None
init = 'he_uniform'
fan_mode = 'fan_in'
init_params = {'a': 0, 'mode': fan_mode, 'nonlinearity': 'relu'}
scale_init = None
bias = False

# %% [markdown]
# ### 2.1. Layers' outputs

# %%
generate_outputs_plots(figsize, L, Ms, d, x, init, init_params, n_trials, scaling, bias=False, prefix=fan_mode)

# %% [markdown]
# ## 2.2 Layer's gradients

# %%
generate_gradients_plots(figsize, L, Ms, d, x, init, init_params, n_trials, scaling, bias=False, prefix=fan_mode)

# %% [markdown]
# # 3. He fan_out init without any scaling

# %%
scaling = None
init = 'he_uniform'
fan_mode = 'fan_out'
init_params = {'a': 0, 'mode': fan_mode, 'nonlinearity': 'relu'}
scale_init = None
bias = False

# %% [markdown]
# ## 3.1. Layers' outputs

# %%
generate_outputs_plots(figsize, L, Ms, d, x, init, init_params, n_trials, scaling, bias=False, prefix=fan_mode)

# %% [markdown]
# ## 3.2 Layer's gradients

# %%
generate_gradients_plots(figsize, L, Ms, d, x, init, init_params, n_trials, scaling, bias=False, prefix=fan_mode)
