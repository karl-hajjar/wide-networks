# %% [markdown]
# # 4. MF scaling with Glorot init rescaled by $m$

# %%
scaling = 'mf'
scale_init = 'lin'
init = 'glorot_uniform'
init_params = {'gain': 2.0}
bias = False

# %% [markdown]
# ### 4.1. Layers' outputs

# %%
generate_outputs_plots(figsize, L, Ms, d, x, init, init_params, n_trials, scaling=None, bias=bias, 
                       scale_init=None)

# %%
generate_outputs_plots(figsize, L, Ms, d, x, init, init_params, n_trials, scaling, bias=bias, scale_init=scale_init)

# %% [markdown]
# ## 4.2 Layers' gradients

# %%
generate_gradients_plots(figsize, L, Ms, d, x, init, init_params, n_trials, scaling=None, bias=bias, 
                         scale_init=None)

# %%
generate_gradients_plots(figsize, L, Ms, d, x, init, init_params, n_trials, scaling, bias=bias, 
                         scale_init=scale_init)

# %% [markdown]
# ## 2.3 Layers' rescaled gradients

# %%
generate_rescaled_gradients_plots(figsize, L, Ms, d, x, init, init_params, n_trials, scaling, bias=bias, 
                                  scale_init=scale_init)

# %%
generate_rescaled_gradients_plots(figsize, L, Ms, d, x, init, init_params, n_trials, scaling, bias=bias, 
                                  scale_init=None)
